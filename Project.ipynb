# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("instadataset.csv",low_memory=False)

# %%
data
# Out:
#                      Name  Rank                          Category  \
# 0               cristiano     1                Sports with a ball
# 1                leomessi     2          Sports with a ballFamily
# 2           kendalljenner     3                   ModelingFashion
# 3            arianagrande     4                             Music
# 4                 zendaya     5  Cinema & Actors/actressesFashion
# ..                    ...   ...                               ...
# 995  nimratkhairaofficial   996                             Music
# 996          hanhyojoo222   997   TravelCinema & Actors/actresses
# 997          memphisdepay   998                Sports with a ball
# 998   arminzareeiofficial   999                               NaN
# 999             noorstars  1000                             Shows
#
#      Followers in millions Audience Country  Authentic Engagement in M  \
# 0                462900000            India                        5.5
# ...

# %%
data.rename(columns={'Followers in millions':'Followers'},inplace = True)
data.rename(columns={'Authentic Engagement in M':'Authentic Engagement'},inplace = True)
data.rename(columns={'Engagement Avg. in M':'Engagement Avg.'},inplace = True)

# %%
data.head()
# Out:
#             Name  Rank                          Category  Followers  \
# 0      cristiano     1                Sports with a ball  462900000
# 1       leomessi     2          Sports with a ballFamily  347200000
# 2  kendalljenner     3                   ModelingFashion  247600000
# 3   arianagrande     4                             Music  321400000
# 4        zendaya     5  Cinema & Actors/actressesFashion  147000000
#
#   Audience Country  Authentic Engagement  Engagement Avg.
# 0            India                   5.5              6.6
# 1        Argentina                   3.6              4.8
# 2    United States                   3.0              4.9
# 3    United States                   2.4              3.4
# 4    United States                   4.3              5.8

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
data
# Out:
#                              Name  Rank  \
# 0                       cristiano     1
# 1                        leomessi     2
# 2                   kendalljenner     3
# 3                    arianagrande     4
# 4                         zendaya     5
# 5                   kimkardashian     6
# 6                     taylorswift     7
# 7                     kyliejenner     8
# 8                     selenagomez     9
# 9                             thv    10
# 10                   lalalalisa_m    11
# 11                 jennierubyjane    12
# 12                    virat.kohli    13
# 13                 tomholland2013    14
# 14                            j.m    15
# 15                         agustd    16
# 16                            jin    17
# 17                        beyonce    18
# 18                khloekardashian    19
# 19                      sooyaaa__    20
# 20                   billieeilish    21
# 21                       neymarjr    22
# ...

# %%
data.fillna(0)
# Out:
#                              Name  Rank  \
# 0                       cristiano     1
# 1                        leomessi     2
# 2                   kendalljenner     3
# 3                    arianagrande     4
# 4                         zendaya     5
# 5                   kimkardashian     6
# 6                     taylorswift     7
# 7                     kyliejenner     8
# 8                     selenagomez     9
# 9                             thv    10
# 10                   lalalalisa_m    11
# 11                 jennierubyjane    12
# 12                    virat.kohli    13
# 13                 tomholland2013    14
# 14                            j.m    15
# 15                         agustd    16
# 16                            jin    17
# 17                        beyonce    18
# 18                khloekardashian    19
# 19                      sooyaaa__    20
# 20                   billieeilish    21
# 21                       neymarjr    22
# ...

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  1000 non-null   object
#  1   Rank                  1000 non-null   int64
#  2   Category              916 non-null    object
#  3   Followers             1000 non-null   int64
#  4   Audience Country      986 non-null    object
#  5   Authentic Engagement  1000 non-null   float64
#  6   Engagement Avg.       1000 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 54.8+ KB

# %%
data.columns
# Out:
# Index(['Name', 'Rank', 'Category', 'Followers', 'Audience Country',
#        'Authentic Engagement', 'Engagement Avg.'],
#       dtype='object')

# %%
data.describe()
# Out:
#               Rank     Followers  Authentic Engagement  Engagement Avg.
# count  1000.000000  1.000000e+03           1000.000000      1000.000000
# mean    500.500000  2.604460e+07            302.163500       335.498900
# std     288.819436  4.409884e+07            244.203526       269.317813
# min       1.000000  1.600000e+06              0.000000         1.000000
# 25%     250.750000  8.600000e+06            118.800000       128.125000
# 50%     500.500000  1.410000e+07            238.350000       283.050000
# 75%     750.250000  2.542500e+07            447.000000       529.200000
# max    1000.000000  5.284000e+08            990.900000       998.200000

# %%
# How to Show Audience from which Country We have Most Number of followers

# %%
data['Audience Country'].value_counts(normalize=True).round(2)  # round(2) che ee value 2 decimals sudhi jova mate chhe
# Out:
# United States           0.28
# India                   0.16
# Brazil                  0.15
# Indonesia               0.14
# Mexico                  0.04
# Spain                   0.03
# Russia                  0.03
# Argentina               0.02
# Iran                    0.02
# Turkey                  0.02
# United Kingdom          0.02
# Italy                   0.02
# South Korea             0.01
# Colombia                0.01
# Philippines             0.01
# Thailand                0.01
# France                  0.01
# Egypt                   0.01
# Iraq                    0.00
# Germany                 0.00
# Japan                   0.00
# Nigeria                 0.00
# Morocco                 0.00
# United Arab Emirates    0.00
# China                   0.00
# Chile                   0.00
# Albania                 0.00
# Kazakhstan              0.00
# Syria                   0.00
# Senegal                 0.00
# Algeria                 0.00
# Poland                  0.00
# ...

# %%
# (who is having more follower from india)
data_ind=data[data['Audience Country'] == 'India']
data_ind.head()
# Out:
#             Name  Rank            Category  Followers Audience Country  \
# 0      cristiano     1  Sports with a ball  462900000            India
# 12   virat.kohli    13  Sports with a ball  206900000            India
# 22       khaby00    23  Sports with a ball   78600000            India
# 23  justinbieber    24               Music  245900000            India
# 28     instagram    29         Photography  528400000            India
#
#     Authentic Engagement  Engagement Avg.
# 0                    5.5              6.6
# 12                   2.1              2.4
# 22                   2.8              3.9
# 23                 798.5              1.2
# 28                 339.6            434.3

# %%
# ( who is having more follower from usa)
data_usa=data[data['Audience Country'] == 'United States']
data_usa.head()
# Out:
#             Name  Rank                          Category  Followers  \
# 2  kendalljenner     3                   ModelingFashion  247600000
# 3   arianagrande     4                             Music  321400000
# 4        zendaya     5  Cinema & Actors/actressesFashion  147000000
# 5  kimkardashian     6                     FashionBeauty  323600000
# 7    kyliejenner     8             FashionModelingBeauty  357000000
#
#   Audience Country  Authentic Engagement  Engagement Avg.
# 2    United States                   3.0              4.9
# 3    United States                   2.4              3.4
# 4    United States                   4.3              5.8
# 5    United States                   1.7              2.5
# 7    United States                   1.2              1.9

# %%
# Audience for a particular category
fashion=data_usa[data_usa['Category'].str.contains('Fashion',na=False)]
fashion
# Out:
#               Name  Rank                               Category  Followers  \
# 2    kendalljenner     3                        ModelingFashion  247600000
# 4          zendaya     5       Cinema & Actors/actressesFashion  147000000
# 5    kimkardashian     6                          FashionBeauty  323600000
# 7      kyliejenner     8                  FashionModelingBeauty  357000000
# 17         beyonce    18                           MusicFashion  267400000
# 31       iamcardib    32                           MusicFashion  137300000
# 45     harrystyles    46                           MusicFashion   46300000
# 359       demirose   360               ModelingLifestyleFashion   19900000
# 497           hshq   498  MusicCinema & Actors/actressesFashion    6300000
# 639    taylor_hill   640             Art/ArtistsFashionModeling   19900000
# 644     troyesivan   645                Art/ArtistsFashionMusic   13200000
# ...

# %%
sports=data_ind[data_ind['Category'].str.contains('Sports',na=False)]
sports
# Out:
#                   Name  Rank                     Category  Followers  \
# 0            cristiano     1           Sports with a ball  462900000
# 12         virat.kohli    13           Sports with a ball  206900000
# 22             khaby00    23           Sports with a ball   78600000
# 164      rohitsharma45   165  Sports with a ballLifestyle   24400000
# 205     hardikpandya93   206           Sports with a ball   21700000
# 215       davidbeckham   216     FamilySports with a ball   74500000
# 238            klrahul   239           Sports with a ball   12900000
# 267    sachintendulkar   268  Sports with a ballLifestyle   35100000
# 488  indiancricketteam   489           Sports with a ball   24600000
# 506     abdevilliers17   507  Sports with a ballLifestyle   18400000
# 575    smriti_mandhana   576           Sports with a ball    6200000
# 619           juventus   620           Sports with a ball   54000000
#
#     Audience Country  Authentic Engagement  Engagement Avg.
# ...

# %%
sports=data[data['Category'].str.contains('Sports',na=False)]
sports
# Out:
#                      Name  Rank                                   Category  \
# 0               cristiano     1                         Sports with a ball
# 1                leomessi     2                   Sports with a ballFamily
# 12            virat.kohli    13                         Sports with a ball
# 21               neymarjr    22                         Sports with a ball
# 22                khaby00    23                         Sports with a ball
# 39              kingjames    40                         Sports with a ball
# 55               k.mbappe    56                         Sports with a ball
# 70   iamzlatanibrahimovic    71                         Sports with a ball
# 71                mosalah    72                         Sports with a ball
# 76            paulodybala    77                         Sports with a ball
# 79             realmadrid    80                         Sports with a ball
# ...

# %%
music=data[data['Category'].str.contains('Music',na=False)]
music
# Out:
#                              Name  Rank  \
# 3                    arianagrande     4
# 6                     taylorswift     7
# 8                     selenagomez     9
# 10                   lalalalisa_m    11
# 11                 jennierubyjane    12
# 17                        beyonce    18
# 19                      sooyaaa__    20
# 20                   billieeilish    21
# 23                   justinbieber    24
# 24                roses_are_rosie    25
# 25                      uarmyhope    26
# 26                     badbunnypr    27
# 27                     nickiminaj    28
# 29                    jungkook.97    30
# 30             bts.bighitofficial    31
# 31                      iamcardib    32
# 33                         karolg    34
# 34                           zayn    35
# 38                            jlo    39
# 41                          adele    42
# 43                  champagnepapi    44
# 45                    harrystyles    46
# ...

# %%
data = data.astype({'Followers':'int','Authentic Engagement':'int','Engagement Avg.':'int'})
data.head()
# Out:
#             Name  Rank                          Category  Followers  \
# 0      cristiano     1                Sports with a ball  462900000
# 1       leomessi     2          Sports with a ballFamily  347200000
# 2  kendalljenner     3                   ModelingFashion  247600000
# 3   arianagrande     4                             Music  321400000
# 4        zendaya     5  Cinema & Actors/actressesFashion  147000000
#
#   Audience Country  Authentic Engagement  Engagement Avg.
# 0            India                     5                6
# 1        Argentina                     3                4
# 2    United States                     3                4
# 3    United States                     2                3
# 4    United States                     4                5

# %%
top20Followers = data.nlargest(20,'Followers')
top20Followers
# Out:
#                 Name  Rank                                          Category  \
# 28         instagram    29                                       Photography
# 0          cristiano     1                                Sports with a ball
# 7        kyliejenner     8                             FashionModelingBeauty
# 1           leomessi     2                          Sports with a ballFamily
# 8        selenagomez     9                                    MusicLifestyle
# 40           therock    41            Cinema & Actors/actressesFitness & Gym
# 5      kimkardashian     6                                     FashionBeauty
# 3       arianagrande     4                                             Music
# 17           beyonce    18                                      MusicFashion
# 18   khloekardashian    19                       Clothing & OutfitsLifestyle
# 2      kendalljenner     3                                   ModelingFashion
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(12,8))
fig2=plt.bar(top20Followers.Category,top20Followers.Followers,label='Folloers in Millions',width=0.8,color='orange')
plt.xticks(fontsize=12,rotation=90)
plt.ylabel("Followers in Millions",fontsize=16)
plt.xlabel("Category",fontsize=16)
plt.title("Top Twenty Countries by followers",fontsize=20)
plt.tight_layout()
plt.ticklabel_format(axis="y",style="plain")

# %%
# Piechart
types=data.Category.value_counts()
types.reset_index()
# Out:
#                                                  index  Category
# 0                                                Music       167
# 1                            Cinema & Actors/actresses       149
# 2                                   Sports with a ball       105
# 3                                            Lifestyle        77
# 4                                             Modeling        19
# 5                                                Shows        19
# 6                       MusicCinema & Actors/actresses        19
# 7                              Humor & Fun & Happiness        15
# 8                                       LifestyleMusic        13
# 9                                               Beauty        13
# 10                  Cinema & Actors/actressesLifestyle        13
# 11                                       Fitness & Gym        12
# 12                      ShowsCinema & Actors/actresses         9
# ...

# %%
plt.pie(types.values,labels=types.index,labeldistance=1.2,autopct='%1.2f%%',shadow=True,startangle=60)
plt.title('Different categories',fontsize=20)
plt.plot()
# Out:
# []
